# %% [markdown]
# # Data Understanding

# %% [markdown]
# ## Importing the Libraries and Dataset

# %%
import numpy as np
import pandas as pd

columns = ['duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes', 'land',
           'wrong_fragment', 'urgent', 'hot', 'num_failed_logins', 'logged_in', 'num_compromised',
           'root_shell', 'su_attempted', 'num_root', 'num_file_creations', 'num_shells', 'num_access_files',
           'num_outbound_cmds', 'is_host_login', 'is_guest_login', 'count', 'srv_count', 'serror_rate',
           'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate', 'same_srv_rate', 'diff_srv_rate',
           'srv_diff_host_rate', 'dst_host_count', 'dst_host_srv_count', 'dst_host_same_srv_rate',
           'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate', 'dst_host_srv_diff_host_rate',
           'dst_host_serror_rate', 'dst_host_srv_serror_rate', 'dst_host_rerror_rate', 'dst_host_srv_rerror_rate',
           'attack', 'level']

data = pd.read_csv('https://raw.githubusercontent.com/AhmedB255/BINF-820---Bachelor-Thesis/main/KDDTrain%2B.csv',
                  names=columns)

data.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.17
# 1               0       0    0  ...                    0.00
# 2               0       0    0  ...                    0.10
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    1.00
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    0.03                         0.17
# 1                    0.60                         0.88
# ...

# %%
data.shape
# Out:
# (125973, 43)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125973 entries, 0 to 125972
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   duration                     125973 non-null  int64
#  1   protocol_type                125973 non-null  object
#  2   service                      125973 non-null  object
#  3   flag                         125973 non-null  object
#  4   src_bytes                    125973 non-null  int64
#  5   dst_bytes                    125973 non-null  int64
#  6   land                         125973 non-null  int64
#  7   wrong_fragment               125973 non-null  int64
#  8   urgent                       125973 non-null  int64
#  9   hot                          125973 non-null  int64
#  10  num_failed_logins            125973 non-null  int64
#  11  logged_in                    125973 non-null  int64
# ...

# %%
data.describe()
# Out:
#            duration     src_bytes     dst_bytes           land  \
# count  125973.00000  1.259730e+05  1.259730e+05  125973.000000
# mean      287.14465  4.556674e+04  1.977911e+04       0.000198
# std      2604.51531  5.870331e+06  4.021269e+06       0.014086
# min         0.00000  0.000000e+00  0.000000e+00       0.000000
# 25%         0.00000  0.000000e+00  0.000000e+00       0.000000
# 50%         0.00000  4.400000e+01  0.000000e+00       0.000000
# 75%         0.00000  2.760000e+02  5.160000e+02       0.000000
# max     42908.00000  1.379964e+09  1.309937e+09       1.000000
#
#        wrong_fragment         urgent            hot  num_failed_logins  \
# count   125973.000000  125973.000000  125973.000000      125973.000000
# mean         0.022687       0.000111       0.204409           0.001222
# std          0.253530       0.014366       2.149968           0.045239
# min          0.000000       0.000000       0.000000           0.000000
# ...

# %% [markdown]
# # Data Preparation

# %% [markdown]
# In this phase, we will preprocess the data using multiple techniques to make suitable for analysis using a machine learning model.

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# First, we will check for any null values.

# %%
data.isnull().any()
# Out:
# duration                       False
# protocol_type                  False
# service                        False
# flag                           False
# src_bytes                      False
# dst_bytes                      False
# land                           False
# wrong_fragment                 False
# urgent                         False
# hot                            False
# num_failed_logins              False
# logged_in                      False
# num_compromised                False
# root_shell                     False
# su_attempted                   False
# num_root                       False
# num_file_creations             False
# num_shells                     False
# num_access_files               False
# num_outbound_cmds              False
# is_host_login                  False
# is_guest_login                 False
# count                          False
# srv_count                      False
# serror_rate                    False
# ...

# %%
for col in data.select_dtypes(object):
    print(f"Number of empty strings in column {col} : {data[col].isin(['']).sum(axis=0)}")
    print(f"Number of only space strings in column {col} : {data[col].isin([' ']).sum(axis=0)}")
# Out:
# Number of empty strings in column protocol_type : 0
# Number of only space strings in column protocol_type : 0
# Number of empty strings in column service : 0
# Number of only space strings in column service : 0
# Number of empty strings in column flag : 0
# Number of only space strings in column flag : 0
# Number of empty strings in column attack : 0
# Number of only space strings in column attack : 0

# %% [markdown]
# ## Data Integration

# %% [markdown]
# The dataset comes from only one source. So, this step will be skipped.

# %% [markdown]
# ## Data Transformation

# %% [markdown]
# Let's look at the unique values of categorical columns.

# %%
categorical_vars = []

for col in data.select_dtypes(object):
    categorical_vars.append(col)
    print(f"{data[col]} : {data[col].unique()}")
    print("=======================================")
# Out:
# 0         tcp
# 1         udp
# 2         tcp
# 3         tcp
# 4         tcp
#          ...
# 125968    tcp
# 125969    udp
# 125970    tcp
# 125971    tcp
# 125972    tcp
# Name: protocol_type, Length: 125973, dtype: object : ['tcp' 'udp' 'icmp']
# ...
# 0         ftp_data
# 1            other
# 2          private
# 3             http
# 4             http
#             ...
# 125968     private
# 125969     private
# 125970        smtp
# 125971      klogin
# 125972    ftp_data
# Name: service, Length: 125973, dtype: object : ['ftp_data' 'other' 'private' 'http' 'remote_job' 'name' 'netbios_ns'
#  'eco_i' 'mtp' 'telnet' 'finger' 'domain_u' 'supdup' 'uucp_path' 'Z39_50'
#  'smtp' 'csnet_ns' 'uucp' 'netbios_dgm' 'urp_i' 'auth' 'domain' 'ftp'
#  'bgp' 'ldap' 'ecr_i' 'gopher' 'vmnet' 'systat' 'http_443' 'efs' 'whois'
#  'imap4' 'iso_tsap' 'echo' 'klogin' 'link' 'sunrpc' 'login' 'kshell'
#  'sql_net' 'time' 'hostnames' 'exec' 'ntp_u' 'discard' 'nntp' 'courier'
# ...

# %% [markdown]
# They all seem like ordinal categorical features. Let's specify that.

# %%
for col in data.select_dtypes(object):
    data[col] = pd.Categorical(data[col], categories=data[col].unique(), ordered=True)

for col in categorical_vars:
    print(data[col].iloc[:4])
# Out:
# 0    tcp
# 1    udp
# 2    tcp
# 3    tcp
# Name: protocol_type, dtype: category
# Categories (3, object): ['tcp' < 'udp' < 'icmp']
# 0    ftp_data
# 1       other
# 2     private
# 3        http
# Name: service, dtype: category
# Categories (70, object): ['ftp_data' < 'other' < 'private' < 'http' ... 'aol' < 'http_2784' < 'tftp_u' < 'harvest']
# 0    SF
# 1    SF
# 2    S0
# 3    SF
# Name: flag, dtype: category
# Categories (11, object): ['SF' < 'S0' < 'REJ' < 'RSTR' ... 'RSTOS0' < 'S3' < 'S2' < 'OTH']
# 0     normal
# 1     normal
# 2    neptune
# 3     normal
# Name: attack, dtype: category
# Categories (23, object): ['normal' < 'neptune' < 'warezclient' < 'ipsweep' ... 'land' < 'loadmodule' < 'spy' < 'perl']

# %% [markdown]
# Good. Because they are ordinal categorical columns, we will encode them using label encoding.

# %%
for col in categorical_vars:
    data[col] = data[col].astype('category').cat.codes
    
data.head()
# Out:
#    duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0         0              0        0     0        491          0     0
# 1         0              1        1     0        146          0     0
# 2         0              0        2     1          0          0     0
# 3         0              0        3     0        232       8153     0
# 4         0              0        3     0        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0               0       0    0  ...                    0.17
# 1               0       0    0  ...                    0.00
# 2               0       0    0  ...                    0.10
# 3               0       0    0  ...                    1.00
# 4               0       0    0  ...                    1.00
#
#    dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    0.03                         0.17
# 1                    0.60                         0.88
# ...

# %% [markdown]
# The data looks good. We will now create the columns that we will use as a target column for classification.

# %%
data['is_anomaly'] = data['attack'].map(lambda a: 0 if a == 0 else 1)

data.head()
# Out:
#    duration  protocol_type  service  flag  src_bytes  dst_bytes  land  \
# 0         0              0        0     0        491          0     0
# 1         0              1        1     0        146          0     0
# 2         0              0        2     1          0          0     0
# 3         0              0        3     0        232       8153     0
# 4         0              0        3     0        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_diff_srv_rate  \
# 0               0       0    0  ...                    0.03
# 1               0       0    0  ...                    0.60
# 2               0       0    0  ...                    0.05
# 3               0       0    0  ...                    0.00
# 4               0       0    0  ...                    0.00
#
#    dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \
# 0                         0.17                         0.00
# ...

# %%
data.hist(figsize=(30, 30))
# Out:
# array([[<AxesSubplot:title={'center':'duration'}>,
#         <AxesSubplot:title={'center':'protocol_type'}>,
#         <AxesSubplot:title={'center':'service'}>,
#         <AxesSubplot:title={'center':'flag'}>,
#         <AxesSubplot:title={'center':'src_bytes'}>,
#         <AxesSubplot:title={'center':'dst_bytes'}>,
#         <AxesSubplot:title={'center':'land'}>],
#        [<AxesSubplot:title={'center':'wrong_fragment'}>,
#         <AxesSubplot:title={'center':'urgent'}>,
#         <AxesSubplot:title={'center':'hot'}>,
#         <AxesSubplot:title={'center':'num_failed_logins'}>,
#         <AxesSubplot:title={'center':'logged_in'}>,
#         <AxesSubplot:title={'center':'num_compromised'}>,
#         <AxesSubplot:title={'center':'root_shell'}>],
#        [<AxesSubplot:title={'center':'su_attempted'}>,
#         <AxesSubplot:title={'center':'num_root'}>,
#         <AxesSubplot:title={'center':'num_file_creations'}>,
#         <AxesSubplot:title={'center':'num_shells'}>,
# ...

# %% [markdown]
# Good. Let's use our two machine learning algorithms before using feature selection.

# %% [markdown]
# ## Modelling (Without Feature Selection)

# %% [markdown]
# First, we will create the method through which the models' metrics will be displayed.

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

def print_scores(clf, X_train, X_test, y_train, y_test, train=True):
    if train:
        pred = clf.predict(X_train)
        clf_report = pd.DataFrame(classification_report(y_train, pred, output_dict=True))
        print('Training Results:')
        print('=================================================')
        print(f"Accuracy Score: {accuracy_score(y_train, pred) * 100:.7f}%")
        print('=================================================')
        print(f"Classification Report: \n{clf_report}")
        print('=================================================')
        print(f"Confusion Matrix: \n{confusion_matrix(y_train, pred)}")
    else:
        pred = clf.predict(X_test)
        clf_report = pd.DataFrame(classification_report(y_test, pred, output_dict=True))
        print('Test Results:')
        print('=================================================')
        print(f"Accuracy Score: {accuracy_score(y_test, pred) * 100:.7f}%")
        print('=================================================')
        print(f"Classification Report: \n{clf_report}")
        print('=================================================')
        print(f"Confusion Matrix: \n{confusion_matrix(y_test, pred)}")

# %% [markdown]
# Next, we will split the dataset into a training dataset and a testing dataset.

# %%
from sklearn.model_selection import train_test_split

X = data.drop('is_anomaly', axis=1)
y = data['is_anomaly']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# Next, we will determine the right cross-validation score.

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB

clf = DecisionTreeClassifier(random_state=42)
skf = StratifiedKFold(n_splits=10)

scores = cross_val_score(clf, X_train, y_train, cv=skf, scoring='f1')
print("Tree Score: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))

clf = GaussianNB()

scores = cross_val_score(clf, X_train, y_train, cv=skf, scoring='f1')
print("Bayes Score: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
# Out:
# Tree Score: 1.00 (+/- 0.00)
# Bayes Score: 0.03 (+/- 0.01)

# %% [markdown]
# Now, we will use two classifiers: decision trees, and naive bayes. Furthermore, we will employ automatic hyperparameter tuning.

# %%
from sklearn.model_selection import GridSearchCV

tree_params = {
    "criterion":("gini", "entropy"), 
    "splitter":("best", "random"), 
    "max_depth":(list(range(1, 20))), 
    "min_samples_split":[2, 3, 4], 
    "min_samples_leaf":list(range(1, 20)),
}

bayes_params = {
    "var_smoothing": np.logspace(0, -15, 100)
}

dtc = DecisionTreeClassifier(random_state=42)

# 5-fold cross-validation
tree_cv = GridSearchCV(dtc, tree_params, scoring='recall', n_jobs=-1, verbose=1, cv=1)
tree_cv.fit(X_train, y_train)
tree_best_params = tree_cv.best_params_

dtc = DecisionTreeClassifier(**tree_best_params)
dtc.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-4558aff78809> in <module>
#      17 # 5-fold cross-validation
#      18 tree_cv = GridSearchCV(dtc, tree_params, scoring='recall', n_jobs=-1, verbose=1, cv=1)
# ---> 19 tree_cv.fit(X_train, y_train)
#      20 tree_best_params = tree_cv.best_params_
#      21
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     650         """
#     651         estimator = self.estimator
# ...

# %%
nbc = GaussianNB()

# 5-fold cross-validation
bayes_cv = GridSearchCV(nbc, bayes_params, scoring='recall', n_jobs=-1, verbose=1, cv=1)
bayes_cv.fit(X_train, y_train)
bayes_best_params = bayes_cv.best_params_

nbc = GaussianNB(**bayes_best_params)
nbc.fit(X_train, y_train)

# %% [markdown]
# Let's see our scores.

# %%
print("Decision Tree Scores:")
print()
print_scores(dtc, X_train, X_test, y_train, y_test, train=True)
print()
print_scores(dtc, X_train, X_test, y_train, y_test, train=False)
print()
print("==========================================")
print()
print("Naive Bayes Scores:")
print()
print_scores(nbc, X_train, X_test, y_train, y_test, train=True)
print()
print_scores(nbc, X_train, X_test, y_train, y_test, train=False)

# %% [markdown]
# ## Data Reduction

# %% [markdown]
# Just like the previous time, we will use feature selection to select the relevant features.

# %%
from sklearn.feature_selection import SelectKBest, f_classif

selector = SelectKBest(f_classif, k=13)

selected_data = selector.fit_transform(X, y)

selected_data.shape

# %%
mask = selector.get_support()
selected_features = []

for bool, feature in zip(mask, X.columns):
    if bool:
        selected_features.append(feature)
        
filtered_data = pd.DataFrame(selected_data, columns=selected_features)

filtered_data.head()

# %%
filtered_data['is_anomaly'] = data['is_anomaly']

filtered_data.head()

# %% [markdown]
# # Modelling

# %%
X = filtered_data.drop('is_anomaly', axis=1)
y = filtered_data['is_anomaly']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
dtc2 = DecisionTreeClassifier(random_state=42)

# 5-fold cross-validation
tree_cv = GridSearchCV(dtc2, tree_params, scoring='recall', n_jobs=-1, verbose=1, cv=5)
tree_cv.fit(X_train, y_train)
tree_best_params = tree_cv.best_params_

dtc2 = DecisionTreeClassifier(**tree_best_params)
dtc2.fit(X_train, y_train)

# %%
nbc2 = GaussianNB()

# 5-fold cross-validation
bayes_cv = GridSearchCV(nbc2, bayes_params, scoring='recall', n_jobs=-1, verbose=1, cv=5)
bayes_cv.fit(X_train, y_train)
bayes_best_params = bayes_cv.best_params_

nbc2 = GaussianNB(**bayes_best_params)
nbc2.fit(X_train, y_train)

# %%
print("Decision Tree Scores:")
print()
print_scores(dtc2, X_train, X_test, y_train, y_test, train=True)
print()
print_scores(dtc2, X_train, X_test, y_train, y_test, train=False)
print()
print("==========================================")
print()
print("Naive Bayes Scores:")
print()
print_scores(nbc2, X_train, X_test, y_train, y_test, train=True)
print()
print_scores(nbc2, X_train, X_test, y_train, y_test, train=False)
